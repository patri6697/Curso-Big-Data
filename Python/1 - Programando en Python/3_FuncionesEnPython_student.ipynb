# %% [markdown]
# # Introducción a las funciones en Python
#
# ### Data Fundamentals con Python
#
# #### Abril 2023
#
# **Aurora Cobo Aguilera**
#
# **The Valley**

# %% [markdown]
# Fragmentos de código definidos de manera que se pueden reutilizar y realizar un determinado algoritmo.
#
# Las funciones pueden recibir uno o más argumentos y a su vez devolver algún resultado o nada.

# %% [markdown]
# # 1. Funciones
#
# ## 1.1 Explicación
#
# A continuación se proponen una serie de ejercicios con funciones para que practiques. Pero recordemos primero cómo se define una función y cómo se utiliza. En el siguiente ejemplo, 'cuadrado' es el nombre de mi función, 'x' es el argumento y como hay un 'return' sabremos que devuelve un valor a la salida cuando usamos dicha función.

# %%
def cuadrado(x):
  return x**2     #tiene un dato de entrada (x) y un dato de salida que es lo que va después del return. 
                # Para utilizar la función, pongo el nombre de la función y entre paréntesis el nombre de la variable
                # print (cuadrado (2))
                # a= 1 + cuadrado (3)
                # print (cuadrado (a*3))

y = 4
y2 = cuadrado(y)
print('El cuadrado de', y, 'es', y2)

# %% [markdown]
# Lo interesante de las funciones es que puedo usarlas cuantas veces quiera en mi programa una vez que estén definidas.

# %%
cuadrado(11)

# %% [markdown]
# **Estructura:**
# import de libreria
# funciones
# programa principal - f(x) definidas o cargadas en mi libreria
# Variables definidas dentro de la función, no existen en mi programa.

# %% [markdown]
# **None** es un tipo de datos especial que significa valor nulo o vacío. Es muy útil en el preprocesado de datos o cuando queremos devolver en una función un error.
# Se utiliza mucho cuando falta algún dato

# %%
cosa = None
if cosa is None:
    print("Es nada")
else:
    print("Es algo")

# %% [markdown]
# Nótese aquí es uso de **is** también para comprobar si algo coincide.

# %% [markdown]
# ### 1.2 Ejercicios
#
# > **Ejercicio**: Diseñe una función llamada *area_circulo* que reciba como parámetro el valor de un radio y devuelva el área de un círculo con dicho radio.

# %%
#<SOL>
from math import pi

def area_circulo(radio):
    area = math.pi * radio**2
    return area

radio = int(input('Indique la medida del radio en cm '))
print (area_circulo(radio))
# Out:
# Indique la medida del radio en cm 12
# 452.3893421169302

# %% [markdown]
# > **Ejercicio**: Defina una función que convierta grados centígrados en grados Farenheit.

# %%
#<SOL>

def conv(t):
  f = t*1.8 + 32
  return f
temp = int (input ('Introduzca la temperatura en ºC '))
print (conv(temp))
#</SOL>
# Out:
# Introduzca la temperatura en ºC 21
# 69.80000000000001

# %% [markdown]
# > **Ejercicio**: Diseñe una función que reciba una cadena y devuelva True si la cadena empieza por minúscula y False en caso contrario.

# %%
#<SOL>
def comienza_con_minuscula(cadena):
    if cadena[0].islower():
        return True
    else:
        return False
cadena = input("Ingresa una cadena: ")
resultado = comienza_con_minuscula(cadena)
print("¿La cadena comienza con minúscula?:", resultado)
#</SOL>
# Out:
# Ingresa una cadena: Amapola
# ¿La cadena comienza con minúscula?: False

# %% [markdown]
# > **Ejercicio**: Diseñe una función que dados los 3 lados de un triángulo, devuelva la longitud de su perímetro.

# %%
#<SOL>
def perímetro (x,y,z):
  p=x+y+z
  return p
x= int(input('Indique la medida del primer lado '))
y = int (input('Indique la medida del segundo lado '))
z = int(input('Indique la medida del tercer lado '))
print (perímetro (x,y,z))
#</SOL>
# Out:
# Indique la medida del primer lado15
# Indique la medida del segundo lado18
# Indique la medida del tercer lado14
# 47

# %% [markdown]
# > **Ejercicio**: Diseñe una función que devuelva la solución de la ecuación lineal ax+b=0, dados a y b. Si la ecuación tiene infinitas soluciones o no tiene solución, la función lo detectará y devolverá None.

# %%
#<SOL>
def ec_lineal (a,b):
  if a ==0:
    print ('La ecuacuón no tiene solución o tiene infinitas soluciones')
    resultado= None
  else:
    resultado =-b/a
  return resultado
a = int (input ('Indique el valor de a '))
b = int (input ('Indique el valor de b '))
print (ec_lineal(a,b))
#</SOL>
# Out:
# Indique el valor de a 0
# Indique el valor de b 12
# La ecuacuón no tiene solución o tiene infinitas soluciones
# None

# %% [markdown]
# > **Ejercicio**: Diseñe una función sin argumentos que devuelva el valor de un número aleatorio entre 0 y 10. Puedes usar la función predefinida *random()* de la librería *radom*.

# %%
#<SOL>
from random import random

def devuelveAleatorio():
  num_aleatorio = 10 * random()     # Pasamos del rango [0, 1] -----> [0, 10]
  return num_aleatorio

print('Numero aleatorio: ', devuelveAleatorio())

#</SOL>
# Out:
# Numero aleatorio:  1.476389484664351

# %% [markdown]
# ###1.3 Ejercicios Extra
#
# > **Ejercicio MÁS DIFÍCIL**: Diseñe una función que dado un número entero, muestre por pantalla sus cifras en orden inverso. Cada cifra aparecerá en una línea diferente. Ojo, aquí no devolvemos ningún valor.

# %%
#<SOL>
def mostrar_cifras_inversas(numero):
    numero_str = str(numero)
    for i in range (len(numero_str)-1,-1,-1):
      print (numero_str[i])
        
numero = int(input("Ingresa un número entero: "))
print ('el numero', numero, ' al revés es')
mostrar_cifras_inversas(numero)
#</SOL>
# Out:
# Ingresa un número entero: 1536
# el numero 1536  al revés es
# 6
# 3
# 5
# 1

# %% [markdown]
# > **Ejercicio EXTRA**: Diseñe una función que nos diga si un número dado como parámetro es perfecto o no. Un número es perfecto si es igual a la suma de todos sus divisores excepto él mismo.

# %%
# <SOL>
def es_perfecto(numero):
    suma_divisores = 0
    for i in range(1, numero):
        if numero % i == 0:
            suma_divisores += i
    if suma_divisores == numero:
        return True
    else:
        return False

numero = int(input("Ingresa un número: "))

if es_perfecto(numero)== True:                 
    print("El número es perfecto") 
else:
    print("El número no es perfecto")
# </SOL>
# Out:
# Ingresa un número: 6
# El número es perfecto

# %% [markdown]
# > **Ejercicio EXTRA!**: Diseñe una función que muestre los números perfectos comprendidos entre 1 y N, siendo N un número pasado como argumento.

# %%
#<SOL>
def numeros_perfectos_hasta_N(N):
  numeros_perfectos = []
  for numero in range(1, N + 1):
    if es_perfecto(numero):
      print(numero)
      numeros_perfectos.append(numero)
  return numeros_perfectos


aa = numeros_perfectos_hasta_N(500)
print(aa)
# Out:
# 6
# 28
# 496
# [6, 28, 496]

# %%
#<SOL>
def numeros_perfectos_hasta_N(N):
    for numero in range(1, N + 1):
        suma_divisores = 0
        for i in range(1, numero):
            if numero % i == 0:
                suma_divisores += i
        if suma_divisores == numero:
            print(numero)

N = int(input("Ingresa un número: "))
print("Números perfectos hasta", N, ":")
numeros_perfectos_hasta_N(N)

#</SOL>
# Out:
# Ingresa un número: 153
# Números perfectos hasta 153 :
# 6
# 28

# %% [markdown]
# ### 1.4 Especificar parámetros con valores por defecto (Extra!)
#
# Es posible especificar valores por defecto en los parámetros de una función. El valor por defecto se usará cuando en la llamada a la función no se haya proporcionado el correspondiente argumento.
#
# Puedes definir una función en la que dé un valor por defecto a un parámetro de entrada.
# Para usar esta función puedo:
# - Darle valores a todos los parámetros
# - Darle valor a los dos primeros, y como el 3 tiene uno por defecto,

# %%
def menu(bebida, entrante, postre='Tiramisú'):
    return {'bebida': bebida, 'entrante': entrante, 'postre': postre}

# %%
# Hacemos uso del valor por defecto del parámetro "postre"
menu('Vino', 'Ensalada')
# Out:
# {'bebida': 'Vino', 'entrante': 'Ensalada', 'postre': 'Tiramisú'}

# %%
# "Sobreescribimos" el valor de "postre" especificando uno concreto
menu('Agua', 'Revuelto de setas', 'Helado')
# Out:
# {'bebida': 'Agua', 'entrante': 'Revuelto de setas', 'postre': 'Helado'}

# %% [markdown]
# Los valores por defecto en los parámetros se calculan cuando se **define** la función, no cuando se **ejecuta**.
